# %% [markdown]
# <a href="https://colab.research.google.com/github/Pushpa-Harshitha05/NLP_Lab/blob/main/Remove_hastag_words.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hi')
# Out:
# hi

# %%
noise_list = ['is','a','this','the','...',' ','.']

def remove_noisedata(input_text):
  input_list = input_text.split()
  real_data = [word for word in input_list if word not in noise_list]
  data = " ".join(real_data)
  return data

print(remove_noisedata("this is the best fruit    ."))
# Out:
# best fruit

# %%
import re

def find_hashWord(text):
  regex = r"#(\w+)"
  matching_words = re.findall(regex,text)
  for word in matching_words:
    print(word)

if __name__ == "__main__":
  print("the words with hashtag are: ")
  find_hashWord("beautiful day #rainy #me #peace")
# Out:
# the words with hashtag are:
# rainy
# me
# peace

# %%
import pandas as pd

# %%
data = pd.read_csv("sample_data/tweets_v8.csv")
data.head()
# Out:
#                     user_name  user_location  \
# 0   the _ûndër-ratèd niggáh👊🏾            NaN
# 1  Best uncle on planet earth            NaN
# 2                      marcie            NaN
# 3                    YoMo.Mdp  Any pronouns
# 4             Laura Reactions         France
#
#                                     user_description  \
# 0  @ManUtd die hard❤️❤️💪🏿💪🏿\n\n\nYOLO\n\n\nJ'ai b...
# 1                                                NaN
# 2  animal crossing. chicken nuggets. baby yoda. s...
# 3  Where the heck is the karma\nI'm going on my s...
# 4  I talk and I make reactions videos about shows...
#
#                 user_created  user_followers  user_friends  user_favourites  \
# 0  2019-09-06 19:24:57+00:00             581          1035             8922
# 1  2013-05-08 19:35:26+00:00             741           730             8432
# 2  2009-02-21 10:31:30+00:00             562          1197            62732
# ...

# %%
data.isna().sum()
# Out:
# user_name               4
# user_location       23870
# user_description     5211
# user_created            0
# user_followers          0
# user_friends            0
# user_favourites         0
# user_verified           0
# date                    0
# text                    0
# source                  0
# is_retweet              0
# dtype: int64

# %%
data.drop('user_location',axis=1,inplace=True)

# %%
data.head()
# Out:
#                     user_name  \
# 0   the _ûndër-ratèd niggáh👊🏾
# 1  Best uncle on planet earth
# 2                      marcie
# 3                    YoMo.Mdp
# 4             Laura Reactions
#
#                                     user_description  \
# 0  @ManUtd die hard❤️❤️💪🏿💪🏿\n\n\nYOLO\n\n\nJ'ai b...
# 1                                                NaN
# 2  animal crossing. chicken nuggets. baby yoda. s...
# 3  Where the heck is the karma\nI'm going on my s...
# 4  I talk and I make reactions videos about shows...
#
#                 user_created  user_followers  user_friends  user_favourites  \
# 0  2019-09-06 19:24:57+00:00             581          1035             8922
# 1  2013-05-08 19:35:26+00:00             741           730             8432
# 2  2009-02-21 10:31:30+00:00             562          1197            62732
# 3  2021-02-14 13:21:22+00:00               3           277             1341
# ...

# %%
data.dropna(axis=0,inplace=True)

# %%
data.isna().sum()
# Out:
# user_name           0
# user_description    0
# user_created        0
# user_followers      0
# user_friends        0
# user_favourites     0
# user_verified       0
# date                0
# text                0
# source              0
# is_retweet          0
# dtype: int64

# %%
data
# Out:
#                        user_name  \
# 0      the _ûndër-ratèd niggáh👊🏾
# 2                         marcie
# 3                       YoMo.Mdp
# 4                Laura Reactions
# 5                     Peyman 🅚🅐🅘
# ...                          ...
# 80013         Spanish News Today
# 80014                 Sale X Low
# 80015                     RevAAA
# 80016             Omo K-Pop News
# 80017           🎃Pumpkin💀Queen 🕸
#
#                                         user_description  \
# 0      @ManUtd die hard❤️❤️💪🏿💪🏿\n\n\nYOLO\n\n\nJ'ai b...
# 2      animal crossing. chicken nuggets. baby yoda. s...
# 3      Where the heck is the karma\nI'm going on my s...
# 4      I talk and I make reactions videos about shows...
# 5      Official @KardiaChain $KAI Ambassador\nMarketi...
# ...                                                  ...
# 80013  The Spain Today Online S.L. group includes Mur...
# 80014  Sale X Low, the cheapest low price online stor...
# ...

# %%
text_columns = data.select_dtypes(include=['object'])
text_columns
# Out:
#                        user_name  \
# 0      the _ûndër-ratèd niggáh👊🏾
# 2                         marcie
# 3                       YoMo.Mdp
# 4                Laura Reactions
# 5                     Peyman 🅚🅐🅘
# ...                          ...
# 80013         Spanish News Today
# 80014                 Sale X Low
# 80015                     RevAAA
# 80016             Omo K-Pop News
# 80017           🎃Pumpkin💀Queen 🕸
#
#                                         user_description  \
# 0      @ManUtd die hard❤️❤️💪🏿💪🏿\n\n\nYOLO\n\n\nJ'ai b...
# 2      animal crossing. chicken nuggets. baby yoda. s...
# 3      Where the heck is the karma\nI'm going on my s...
# 4      I talk and I make reactions videos about shows...
# 5      Official @KardiaChain $KAI Ambassador\nMarketi...
# ...                                                  ...
# 80013  The Spain Today Online S.L. group includes Mur...
# 80014  Sale X Low, the cheapest low price online stor...
# ...

# %%
req_data = text_columns.loc[:,['user_description','text']]
req_data
# Out:
#                                         user_description  \
# 0      @ManUtd die hard❤️❤️💪🏿💪🏿\n\n\nYOLO\n\n\nJ'ai b...
# 2      animal crossing. chicken nuggets. baby yoda. s...
# 3      Where the heck is the karma\nI'm going on my s...
# 4      I talk and I make reactions videos about shows...
# 5      Official @KardiaChain $KAI Ambassador\nMarketi...
# ...                                                  ...
# 80013  The Spain Today Online S.L. group includes Mur...
# 80014  Sale X Low, the cheapest low price online stor...
# 80015                    Review Anything Anyone Anywhere
# 80016                        OMO K-Pop\nNews and Updates
# 80017  Creator of Stuff | Horror fan | Traveler | Bad...
#
#                                                     text
# 0      When life hits and the same time poverty strik...
# 2                                        #Squidgame time
# 3      //Blood on 1st slide\nI'm joining the squidgam...
# ...

# %%
import re

regex = r"#\w+"

def getHashWord(data1):
      return re.sub(regex,'',data1)

for col in req_data.columns:
  req_data[col] = req_data[col].apply(getHashWord)

req_data
# Out:
#                                         user_description  \
# 0      @ManUtd die hard❤️❤️💪🏿💪🏿\n\n\nYOLO\n\n\nJ'ai b...
# 2      animal crossing. chicken nuggets. baby yoda. s...
# 3      Where the heck is the karma\nI'm going on my s...
# 4      I talk and I make reactions videos about shows...
# 5      Official @KardiaChain $KAI Ambassador\nMarketi...
# ...                                                  ...
# 80013  The Spain Today Online S.L. group includes Mur...
# 80014  Sale X Low, the cheapest low price online stor...
# 80015                    Review Anything Anyone Anywhere
# 80016                        OMO K-Pop\nNews and Updates
# 80017  Creator of Stuff | Horror fan | Traveler | Bad...
#
#                                                     text
# 0      When life hits and the same time poverty strik...
# 2                                                   time
# 3      //Blood on 1st slide\nI'm joining the squidgam...
# ...

# %%
data[req_data.columns] = req_data
data
# Out:
#                        user_name  \
# 0      the _ûndër-ratèd niggáh👊🏾
# 2                         marcie
# 3                       YoMo.Mdp
# 4                Laura Reactions
# 5                     Peyman 🅚🅐🅘
# ...                          ...
# 80013         Spanish News Today
# 80014                 Sale X Low
# 80015                     RevAAA
# 80016             Omo K-Pop News
# 80017           🎃Pumpkin💀Queen 🕸
#
#                                         user_description  \
# 0      @ManUtd die hard❤️❤️💪🏿💪🏿\n\n\nYOLO\n\n\nJ'ai b...
# 2      animal crossing. chicken nuggets. baby yoda. s...
# 3      Where the heck is the karma\nI'm going on my s...
# 4      I talk and I make reactions videos about shows...
# 5      Official @KardiaChain $KAI Ambassador\nMarketi...
# ...                                                  ...
# 80013  The Spain Today Online S.L. group includes Mur...
# 80014  Sale X Low, the cheapest low price online stor...
# ...

# %%
get_cols = data.apply(lambda x: '#' in str(x)).any().any()
get_cols
# Out:
# False
